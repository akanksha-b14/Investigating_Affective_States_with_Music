# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
d= DataFrame(pd.read_csv('Music_Sets_Test.csv', usecols= range(4), ))

# %%
d
# Out:
#     Unnamed: 0  SONG 1  SONG 2  SONG 3
# 0            A   UHIS8   UHIE3  UHIH15
# 1            B  UHIS11  UHIE11  UHIH13
# 2            C   UHIS3   UHIE5  UHIH10
# 3            D  UHIS20   UHIE9   UHIH6
# 4            E   UHIS1  UHIE10  UHIH14
# ..         ...     ...     ...     ...
# 994        NaN     NaN     NaN     NaN
# 995        NaN     NaN     NaN     NaN
# 996        NaN     NaN     NaN     NaN
# 997        NaN     NaN     NaN     NaN
# 998        NaN     NaN     NaN     NaN
#
# [999 rows x 4 columns]

# %%
d_selected_rows = d[~d.isnull().any(axis=1)]

# %%
d_selected_rows
# Out:
#    Unnamed: 0  SONG 1  SONG 2  SONG 3
# 0           A   UHIS8   UHIE3  UHIH15
# 1           B  UHIS11  UHIE11  UHIH13
# 2           C   UHIS3   UHIE5  UHIH10
# 3           D  UHIS20   UHIE9   UHIH6
# 4           E   UHIS1  UHIE10  UHIH14
# 5           F   UHIS6  UHIE17  UHIH18
# 6           G  UHIS17   UHIE6   UHIH2
# 7           H  UHIS16   UHIE8  UHIH17
# 8           I   UHIS4  UHIE13  UHIH16
# 9           J  UHIS18   UHIE2   UHIH5
# 10          K  UHIS13  UHIE15   UHIH4
# 11          L  UHIS15   UHIE4  UHIH20
# 12          M   UHIS9   UHIE7   UHIH8
# 13          N  UHIS10   UHIE1   UHIH7
# 14          O   UHIS7  UHIE12  UHIH12
# 15          P  UHIS14  UHIE18  UHIH11
# 16          Q  UHIS19  UHIE16   UHIH1
# 17          R   UHIS2  UHIE20   UHIH3
# 18          S  UHIS12  UHIE14   UHIH9
# 19          T   UHIS5  UHIE19  UHIH19

# %%
d_selected_rows.rename( columns={'Unnamed: 0':'Music_Set'}, inplace=True )
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
d_selected_rows
# Out:
#    Music_Set  SONG 1  SONG 2  SONG 3
# 0          A   UHIS8   UHIE3  UHIH15
# 1          B  UHIS11  UHIE11  UHIH13
# 2          C   UHIS3   UHIE5  UHIH10
# 3          D  UHIS20   UHIE9   UHIH6
# 4          E   UHIS1  UHIE10  UHIH14
# 5          F   UHIS6  UHIE17  UHIH18
# 6          G  UHIS17   UHIE6   UHIH2
# 7          H  UHIS16   UHIE8  UHIH17
# 8          I   UHIS4  UHIE13  UHIH16
# 9          J  UHIS18   UHIE2   UHIH5
# 10         K  UHIS13  UHIE15   UHIH4
# 11         L  UHIS15   UHIE4  UHIH20
# 12         M   UHIS9   UHIE7   UHIH8
# 13         N  UHIS10   UHIE1   UHIH7
# 14         O   UHIS7  UHIE12  UHIH12
# 15         P  UHIS14  UHIE18  UHIH11
# 16         Q  UHIS19  UHIE16   UHIH1
# 17         R   UHIS2  UHIE20   UHIH3
# 18         S  UHIS12  UHIE14   UHIH9
# 19         T   UHIS5  UHIE19  UHIH19

# %%
stacked_df = d_selected_rows.stack()

# %%
#d = DataFrame(stacked_df) 
print(stacked_df, '\n')
# Out:
# 0   Music_Set         A
#     SONG 1        UHIS8
#     SONG 2        UHIE3
#     SONG 3       UHIH15
# 1   Music_Set         B
#                   ...
# 18  SONG 3        UHIH9
# 19  Music_Set         T
#     SONG 1        UHIS5
#     SONG 2       UHIE19
#     SONG 3       UHIH19
# Length: 80, dtype: object

# %%
d = DataFrame(stacked_df)

# %%
d#.head(20) #or in series : stacked_df.head(20)
# Out:
#                    0
# 0  Music_Set       A
#    SONG 1      UHIS8
#    SONG 2      UHIE3
#    SONG 3     UHIH15
# 1  Music_Set       B
# ...              ...
# 18 SONG 3      UHIH9
# 19 Music_Set       T
#    SONG 1      UHIS5
#    SONG 2     UHIE19
#    SONG 3     UHIH19
#
# [80 rows x 1 columns]

# %%
# check the data column names
for col in d.columns:
    print(col)
# Out:
# 0

# %%
d= d.rename(columns={0:"0"})

#d= d.rename(columns={})

# %%
#print(d.columns)
d
# Out:
#                    0
# 0  Music_Set       A
#    SONG 1      UHIS8
#    SONG 2      UHIE3
#    SONG 3     UHIH15
# 1  Music_Set       B
# ...              ...
# 18 SONG 3      UHIH9
# 19 Music_Set       T
#    SONG 1      UHIS5
#    SONG 2     UHIE19
#    SONG 3     UHIH19
#
# [80 rows x 1 columns]

# %%
d2= DataFrame(pd.read_csv('Linked_Songs_Hindi.csv', usecols= range(19), ))

# %%
d_selected_rows2 = d2[~d2.isnull().any(axis=1)]

# %%
d_selected_rows2
# Out:
#    Unnamed: 0  Unnamed: 0.1                      id              artist  \
# 0       UHIS1            33  30yySOIXHZYx94sLAySy2j         A.R. Rahman
# 1       UHIS2            97  2S6N9pbnkhQRyAx80HmF79     Shraddha Kapoor
# 2       UHIS3           248  6gwnKOvdBKkTU4CQ7KpIAu       Shaarib Toshi
# 3       UHIS4           157  0MeoxIZvXjyEgeGTMyZc9T        Arijit Singh
# 4       UHIS5           123  3hp6JfJIxkv3sl7E6p7DQj        Amit Trivedi
# 5       UHIS6           277  0p83RJy9EZ0hlg82xcXH7f       Sachet Tandon
# 6       UHIS7           251  2L2YNB3YIletW4fUtwphDv              Pritam
# 7       UHIS8            96  73y649QhnXdcm6fRdvfraO           Ajay-Atul
# 8       UHIS9           191  7uNnlVit5qDvfOje0pqICF         A.R. Rahman
# 9      UHIS10           172  6P0XrGFaGfNh0ObmhSTKW2     Various Artists
# 10     UHIS11           153  1StFDfq4raRws97W8Wb3QS       Darshan Raval
# 11     UHIS12            24  2sURneAotz0wUnak36GzQY              Pritam
# ...

# %%
for col in d_selected_rows2.columns:
    print(col)
# Out:
# Unnamed: 0
# Unnamed: 0.1
# id
# artist
# album
# name
# length
# danceability
# acousticness
# energy
# instrumentalness
# liveness
# valence
# loudness
# speechiness
# tempo
# key
# time_signature
# mood

# %%
d_selected_rows2= d_selected_rows2.rename(columns={"Unnamed: 0":"0"})

# %%
# merge dataframe - d on col = 0 with dataframe - d_selected_rows2 on col = 0

df_merge = pd.merge(d,d_selected_rows2, on = "0", how = "left")

# %%
df_merge.head(20)
# Out:
#          0  Unnamed: 0.1                      id           artist  \
# 0        A           NaN                     NaN              NaN
# 1    UHIS8          96.0  73y649QhnXdcm6fRdvfraO        Ajay-Atul
# 2    UHIE3          32.0  78LZUVqzZzsuNfT6G782pP       Krsna Solo
# 3   UHIH15           0.0  1gwO79MdYdumgIjxq8eCxB   Vishal-Shekhar
# 4        B           NaN                     NaN              NaN
# 5   UHIS11         153.0  1StFDfq4raRws97W8Wb3QS    Darshan Raval
# 6   UHIE11           8.0  3fPgIknlkDWXs1l2noKZbp          Badshah
# 7   UHIH13           1.0  3bZPdEskcnMdepwCaDSJRl   Vishal-Shekhar
# 8        C           NaN                     NaN              NaN
# 9    UHIS3         248.0  6gwnKOvdBKkTU4CQ7KpIAu    Shaarib Toshi
# 10   UHIE5         202.0  2r32XiAWtZbT3eLUvf4pag      Ram Sampath
# 11  UHIH10          46.0  5aN5zVgz1zAfE6LMxuJYaJ      Navraj Hans
# 12       D           NaN                     NaN              NaN
# ...

# %%
df_merge = df_merge[["0","artist","album","name","length", "danceability", "acousticness", "energy","instrumentalness","liveness", "valence","loudness", "speechiness", "tempo","mood"]]

# %%
df_merge.head()
# Out:
#         0          artist                                              album  \
# 0       A             NaN                                                NaN
# 1   UHIS8       Ajay-Atul     Agneepath (Original Motion Picture Soundtrack)
# 2   UHIE3      Krsna Solo  Tanu Weds Manu Returns (Original Motion Pictur...
# 3  UHIH15  Vishal-Shekhar  I Hate Luv Storys (Original Motion Picture Sou...
# 4       B             NaN                                                NaN
#
#                                      name    length  danceability  \
# 0                                     NaN       NaN           NaN
# 1                    Abhi Mujh Mein Kahin  364786.0         0.334
# 2  Banno (From "Tannu Weds Manu Returns")  196172.0         0.758
# 3                                  Bahara  325706.0         0.595
# 4                                     NaN       NaN           NaN
#
#    acousticness  energy  instrumentalness  liveness  valence  loudness  \
# ...

# %%
#read from Hindi participant list 
p= DataFrame(pd.read_csv('Participants_List_Test.csv', usecols= range(3) ))

# %%
p_selected_rows = p[~p.isnull().any(axis=1)]

# %%
p_selected_rows
# Out:
#                          Participant ID      LEAD MUSIC SET
# 0                  pl1005@srmist.edu.in    Vijaya         A
# 1   pratosh.das@psy.christuniversity.in    Vijaya         B
# 2          vaishnavi1999joshi@gmail.com    Vijaya         C
# 3              tarinisharma03@gmail.com    Vijaya         D
# 4                eashanidas@outlook.com    Vijaya         E
# 5            garimajha41@rocketmail.com    Vijaya         F
# 6                 grad.soumya@gmail.com    Vijaya         G
# 7                  sk7752@srmist.edu.in    Vijaya         H
# 8           kartik.tripathi27@gmail.com    Vijaya         I
# 9           keerthanadeepak@outlook.com    Vijaya         J
# 10              charvitandon8@gmail.com    Vijaya         K
# 11                   shubhayans@gwu.edu    Vijaya         L
# 12                 saanyaseth@gmail.com    Vijaya         M
# 13                  sachiojha@ymail.com    Vijaya         N
# 14                  vickaltym@gmail.com    Vijaya         O
# ...

# %%
for col in p_selected_rows.columns:
    print(col)
# Out:
# Participant ID
# LEAD
# MUSIC SET

# %%
#features_participants_merge = df.merge(p_selected_rows, how = "left", left_on = "0", right_on = "MUSIC SET" )

p_selected_rows= p_selected_rows.rename(columns={"MUSIC SET":"0"})

# %%
#df_merge = pd.merge(d,d_selected_rows2, on = "0", how = "left")

feature_participant_merge = pd.merge(df_merge,p_selected_rows, on = "0", how = "left")

# %%
feature_participant_merge.head(7)
# Out:
#         0          artist                                              album  \
# 0       A             NaN                                                NaN
# 1       A             NaN                                                NaN
# 2   UHIS8       Ajay-Atul     Agneepath (Original Motion Picture Soundtrack)
# 3   UHIE3      Krsna Solo  Tanu Weds Manu Returns (Original Motion Pictur...
# 4  UHIH15  Vishal-Shekhar  I Hate Luv Storys (Original Motion Picture Sou...
# 5       B             NaN                                                NaN
# 6       B             NaN                                                NaN
#
#                                      name    length  danceability  \
# 0                                     NaN       NaN           NaN
# 1                                     NaN       NaN           NaN
# 2                    Abhi Mujh Mein Kahin  364786.0         0.334
# 3  Banno (From "Tannu Weds Manu Returns")  196172.0         0.758
# ...

# %%
feature_participant_merge= feature_participant_merge.rename(columns={"0":"Songs_In_Music_Set"})

# %%
feature_participant_merge = feature_participant_merge.iloc[:,:-1]

# %%
feature_participant_merge
# Out:
#     Songs_In_Music_Set          artist  \
# 0                    A             NaN
# 1                    A             NaN
# 2                UHIS8       Ajay-Atul
# 3                UHIE3      Krsna Solo
# 4               UHIH15  Vishal-Shekhar
# ..                 ...             ...
# 96                   T             NaN
# 97                   T             NaN
# 98               UHIS5    Amit Trivedi
# 99              UHIE19       Ajay-Atul
# 100             UHIH19  Vishal-Shekhar
#
#                                                  album  \
# 0                                                  NaN
# 1                                                  NaN
# 2       Agneepath (Original Motion Picture Soundtrack)
# 3    Tanu Weds Manu Returns (Original Motion Pictur...
# 4    I Hate Luv Storys (Original Motion Picture Sou...
# ..                                                 ...
# 96                                                 NaN
# ...

# %%
feature_participant_merge.to_csv("feature_participant.csv")

# %%
#read from emotion music survey list 
p= DataFrame(pd.read_csv('emotion_music_survey.csv', usecols= range(35)))

# %%
p_selected_rows = p[~p.isnull().any(axis=1)]

# %%
p.head()
# Out:
#                                       |                   |__pMail  \
# 0  016894b5-e9f2-4358-a26e-59544609429c      michellsnowy@live.com
# 1  01897041-13fb-4967-bad2-f8f208671043        mozakavir@gmail.com
# 2  0791e630-5baf-4ac7-82d5-968ae319e3d3  pranay.haridas3@gmail.com
# 3  0a6c39e9-42a8-4176-bde4-78b1f0a32dee  adityavarnad305@gmail.com
# 4  0b78986d-748a-45a1-9ac5-dd76eba2a0f1  yuwashasharma22@gmail.com
#
#   |__answers__ans01 |__answers__ans02 |__answers__ans03 |__answers__ans04  \
# 0               <29            female           english       notSpecific
# 1               <29              male             hindi       notSpecific
# 2               <29              male           english       notSpecific
# 3               <29            female           english       notSpecific
# 4               <29            female             hindi       notSpecific
#
#   |__answers__ans05 |__answers__ans06 |__answers__ans07 |__answers__ans08  \
# ...

# %%
#pick out the columns i want

p_sad_1st_song = p[['|__pMail', '|__answers__ans12a', '|__answers__ans12b', '|__answers__ans12c', '|__answers__ans12d', '|__answers__ans13a','|__answers__ans13b', '|__answers__ans13c', '|__answers__ans13d', 'delta-happy', 'delta-sad', 'delta-angry', 'delta-fearful']]

# %%
p_sad_1st_song
# Out:
#                          |__pMail  |__answers__ans12a  |__answers__ans12b  \
# 0           michellsnowy@live.com                   2                   3
# 1             mozakavir@gmail.com                   5                   1
# 2       pranay.haridas3@gmail.com                   3                   1
# 3       adityavarnad305@gmail.com                   3                   3
# 4       yuwashasharma22@gmail.com                   4                   3
# ..                            ...                 ...                 ...
# 104          saanyaseth@gmail.com                   2                   3
# 105         kangsenghwa@gmail.com                   3                   3
# 106            aannu520@gmail.com                   5                   1
# 107    garimajha41@rocketmail.com                   2                   3
# 108  vaishnavi1999joshi@gmail.com                   3                   2
#
#      |__answers__ans12c  |__answers__ans12d  |__answers__ans13a  \
# ...

# %%
p_sad_1st_song.to_csv("participants_response_sad.csv")
